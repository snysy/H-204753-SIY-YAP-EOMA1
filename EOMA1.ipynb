# %% [markdown]
# # End-of-Module Assessment 1

# %% [markdown]
# ## Instructions
#
# Please read and follow these instructions and specifications carefully.
#
# 1. This test is available from July 22 to 11:59 PM of July 27. We will only grade this test after July 27, and we will only grade it once.
# 2. This test covers Modules 2 to 4. At this point in the course, you are expected to be familiar enough with Python to use the concepts from these modules with finesse.
# 3. Unless otherwise specified, you are not allowed to use any non-standard (i.e., not in the standard library) modules for this test. We must be strict about this on principle. For example, if you use NumPy or Pandas without permission on problems which ask you to process data, we reserve the right to give your answer no credit. If you are unsure whether you are allowed to use a library, ask. (Yes, you can use the csv and json libraries.)
# 4. Answers to problems that are hard-coded, done in another program such as Excel, or go against the learning outcomes in any other manner will be given no credit. If you are unsure whether your approach to a problem goes against the learning outcomes, ask.
# 5. You are encouraged to use only the provided code cell for each number. However, if you _need_ more cells, you may add them. If you do add more cells, make sure to label them very clearly. Code cells that are not clearly labelled will not be checked.
# 6. If you are asked to output files, please write them all to the `output` folder, even if we forget to specify the ./output prefix.
# 7. If we ask you to use an input file, please find the file in the appropriate section's folder. If it is not there, let us know.
#
# Submission instructions:
# 1. Create a NEW GitHub repository. This repository is what you will submit to the Canvas assignment to indicate that you have submitted. Name your repository SECTION-IDNUM-LASTNAME-EOMA1 (e.g., A-199999-ILAGAN-EOMA1).
# 2. Upload the contents of this folder to your repository. This includes the EOMA1.ipynb file, the output folder, and all three section folders.
# 3. To officially submit your assignment, upload the link to your GitHub repository and your duly accomplished COA to the Canvas assignment (just like the normal assignments).
#
# Some notes:
# 1. Joe made some of these items, and Joben made the others. The items will likely have different conventions in the context/briefs. Please follow them carefully anyway.

# %% [markdown]
# ## Section 1: Rudimentary Data Processing (30 points)

# %% [markdown]
# ### Context
#
# One extremely common form of data is the data shared between applications. Nowadays, when applications talk to each other, they send data in the form of JSON using Hypertext Transfer Protocol (HTTP). You will learn more about this in the next module.
#
# For this section, you are to process data from Twitter's API. The results of several requests to Twitter's API about tweets with the keyword "SONA" have been pre-saved in a `.json` file called `./section1/tweets.json`. Please run the following cell to ensure that the file loads properly.

# %%
# execute this cell to load the file

import json
# If the tweets do not load properly, change this path as necessary.
tweets_file = './section1/tweets.json'

with open(tweets_file, "r") as json_file:
    tweets = json.loads(json_file.read())

# Print contents of tweets to make sure things are okay.
print(tweets)
# Out:
# [{'created_at': 'Tue Jul 28 03:25:35 +0000 2020', 'id': 1287952316029521920, 'id_str': '1287952316029521920', 'full_text': 'RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'truncated': False, 'display_text_range': [0, 130], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'watchmejayjay', 'name': 'Kuya Sir #JUNKTERRORLAWNOW', 'id': 2148463897, 'id_str': '2148463897', 'indices': [3, 17]}], 'urls': []}, 'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1334271631, 'id_str': '1334271631', 'name': 'kai', 'screen_name': '_kyladel', 'location': 'Alaska', 'description': 'yessir i listen to hayley kiyoko', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1490, 'friends_count': 551, 'listed_count': 3, 'created_at': 'Sun Apr 07 14:38:46 +0000 2013', 'favourites_count': 46915, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 74517, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'FFFFFF', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1260618870752079873/ul8OMYqw_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1260618870752079873/ul8OMYqw_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1334271631/1589814512', 'profile_link_color': '000000', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': 'FFFFFF', 'profile_text_color': '000000', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Mon Jul 27 11:10:15 +0000 2020', 'id': 1287706865581752321, 'id_str': '1287706865581752321', 'full_text': 'Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'truncated': False, 'display_text_range': [0, 111], 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2148463897, 'id_str': '2148463897', 'name': 'Kuya Sir #JUNKTERRORLAWNOW', 'screen_name': 'watchmejayjay', 'location': '', 'description': "I'm not your Bio teacher", 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 1128, 'friends_count': 388, 'listed_count': 0, 'created_at': 'Tue Oct 22 06:34:00 +0000 2013', 'favourites_count': 6250, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 5642, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twim ...

# %% [markdown]
# ### 1.1
#
# Print out the number of tweets.

# %%
print(len(tweets))
# Out:
# 100

# %% [markdown]
# ### 1.2
#
# Create a list variable called `tweet_texts` that contains the text of the tweets contained in `tweets`.
#
# Afterwards, print `tweet_texts`.

# %%
tweet_texts = []
for tweet in tweets:
    tweet_texts.append(tweet["full_text"])

    print("tweet_texts: ", tweet_texts)
    
#nts: json viewer, format, viewer (e.g full_text:'RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread')
# Out:
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA"]
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq"]
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…']
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5']
# ...
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Quédate con la persona que no te deje ir a dormir sin antes decirte "decansa,soña bonito y recuerda que te quiero mucho".', 'RT @gmanews: LOOK: Pati mga health worker, sumali sa anti-SONA rally kaninang umaga sa UP Diliman. \n\nAyon sa mga dumalo, malala ang mga pro…', "RT @leamaine2019: Hello there, my Queen @mainedcm!\xa0 I'll be attending PRRD's SONA w/ leaders across the globe so I won't be able to tweet f…", 'RT @heroangel17: SONA\nState Of No Accomplishment\n\n🤭✊', 'Difficult step  ...
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Quédate con la persona que no te deje ir a dormir sin antes decirte "decansa,soña bonito y recuerda que te quiero mucho".', 'RT @gmanews: LOOK: Pati mga health worker, sumali sa anti-SONA rally kaninang umaga sa UP Diliman. \n\nAyon sa mga dumalo, malala ang mga pro…', "RT @leamaine2019: Hello there, my Queen @mainedcm!\xa0 I'll be attending PRRD's SONA w/ leaders across the globe so I won't be able to tweet f…", 'RT @heroangel17: SONA\nState Of No Accomplishment\n\n🤭✊', 'Difficult step  ...
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Quédate con la persona que no te deje ir a dormir sin antes decirte "decansa,soña bonito y recuerda que te quiero mucho".', 'RT @gmanews: LOOK: Pati mga health worker, sumali sa anti-SONA rally kaninang umaga sa UP Diliman. \n\nAyon sa mga dumalo, malala ang mga pro…', "RT @leamaine2019: Hello there, my Queen @mainedcm!\xa0 I'll be attending PRRD's SONA w/ leaders across the globe so I won't be able to tweet f…", 'RT @heroangel17: SONA\nState Of No Accomplishment\n\n🤭✊', 'Difficult step  ...

# %% [markdown]
# ### 1.3
#
# Remove duplicate tweet text lines and save the resulting (cleaned-up) list in the same variable `tweet_texts`.

# %%
tweet_texts = list(dict.fromkeys(tweet_texts))
print("tweet_texts: ", tweet_texts)
#print(len(tweet_texts))
#https://www.w3schools.com/python/python_howto_remove_duplicates.asp
# Out:
# tweet_texts:  ['RT @watchmejayjay: Ay di ka nakanood ng SONA? Wag ka mag-alala, ito yung summary ng mga plano ni tatay laban sa COVID 19: A thread', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\カバーアルバムを引っさげたツアー映像🎥/\n\nツアー映像『J-JUN LIVE 2019～Love Covers～』本日入荷しました🙌\n2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤!!!\n\nCDがあれば…', '@kapilkolotya @kharaa_sona_ Bhai jo le liya hai mene 3saal pehle usko me Boycott kr duga. But\n\nMujy Made in india IPHONE dedo.', 'RT @TOWER_Namba: 【#ジェジュン】\n\n\\ジェジュンの優しく、深い歌声がしみわたる..../\n\nカバーアルバム『Love Covers Ⅱ』本日入荷しました🙌\n原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪\n\n🎁タワレコ特典はアナザージャ…', 'RT @JaDineTrash: Her own time. \nHer own thoughts. \nHer own style. \n\nThank you, Nadine. The battles you fight have always been for a bigger…', 'RT @Absolutalbert: VP isn’t invited to SONA? \n\nDesignated Survivor.', 'RT @cnnphilippines: THREAD: Duterte pushed for the reimposition of capital punishment, specifying the method of lethal injection, for heino…', 'RT @quarkhenares: WHY. WHY DO THEY EVEN GET FILMMAKERS TO SHOOT THE FUCKING SONA', 'RT @Hashtag_nikko13: Di ko nakita yung sona😢😢\nHayaan ko na nga di rin naman nila tayo nakikita', "I hope that we can get some or the same treatment of clarity, purpose &amp; the fastness to support the passage of the Bayanihan [to Recover as One Act], which will supplement funds for recovery &amp; response against the impact of the #COVID-19 pandemic.\n\n-President #Duterte's 5th #SONA", 'RT @gmanews: Philippine neighbors standing up to China without war, Carpio tells Duterte after SONA https://t.co/nieAExKbCu', '@ReaperSZN__ Stupid no-maskers ruining the fun for everyone, online &amp; off 😭😭', 'RT @iamkarendavila: Okay, clearly Senator Franklin Drilon is in the President’s consciousness. Mentioning him again in the SONA. Calls him…', 'OUR MARAWI:  Fake News: Walang Human rights Violation sa Martial Law ni Duterte sabi nya sa kanyang SONA https://t.co/YDt5a7f6KI \n\n#ThisIsOurMindanao', "RT @Joseph_Morong: Tadah! Highlights of Pres. Duterte's 5th SONA @gmanews https://t.co/bc4vfGyRpq", '@marvsmodel Maliban sa war sila ni vice, nasa SONA pala siya. 😁', '@serahphymn Totally a 5 🥺 If my sona met him they would totally vibe', '@Fahmiraza1Raza @ajmaljami Bhai kachra dumping ka name sona  hy kbhi??? Kachra paida hona ha gvt na osko dispose krna ha jab ni hoga ya hoga log kahan dumpkry batao', 'RT @HMV_Kawasaki: 【#ジェジュン】大ヒットしたカバーアルバムの第2弾「Love Covers II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「J-JUN LIVE…', 'RT @rapplerdotcom: "The message seems clear: Smart and Globe go the way of ABS-CBN if they cannot clear the creative legal hurdles that wil…', 'Evanu thala kaga varala elan fc page ku tha fans ya erkanga yaru tag sona enada kiruiu ko🔥gala\n#valimai #ThalaAjith #Ajithkumar https://t.co/hQ14YGO6lU', 'LIST: 21 priority bills of Duterte in SONA 2020 | by @maracepeda \n\nhttps://t.co/CSiWT3lZ3O', '@ABSCBNNews @_katrinadomingo did we watch the same version of SONA?? Iba ata napanood ni Imee', 'RT @ItsACsLife: the fact that this year’s SONA won’t reach the whole nation because the only station that can reach everyone nationwide was…', 'RT @HanssensAnthony: Here is my sona ^^ https://t.co/x0aw68yuY5', 'DDS: "Mag SONA kayo ng inyo"\n\nLIKE ANO NA NAMAN YAN? AMPOTA HAHAHA', "May I again reiterate my thanks to you, the men and women of Congress, for the effort you invested into passing that law.\n\n-President Rodrigo Roa #Duterte's 5th #SONA", 'Quédate con la persona que no te deje ir a dormir sin antes decirte "decansa,soña bonito y recuerda que te quiero mucho".', 'RT @gmanews: LOOK: Pati mga health worker, sumali sa anti-SONA rally kaninang umaga sa UP Diliman. \n\nAyon sa mga dumalo, malala ang mga pro…', "RT @leamaine2019: Hello there, my Queen @mainedcm!\xa0 I'll be attending PRRD's SONA w/ leaders across the globe so I won't be able to tweet f…", 'RT @heroangel17: SONA\nState Of No Accomplishment\n\n🤭✊', 'Difficult step .\nMere liye kar lega rohit....me kar lunga sona ko step pasand he 🙂.\n\n ...

# %% [markdown]
# ### 1.4
#
# We will now perform a very simple word count on the texts.
#
# We have provided a dictionary called `words_dict`. Your code in the next cell should process the tweets such that `words_dict` will contain key-value pairs where the key is a unique word and where the value is the number of times the word appears across all of the texts.
#
# For each text, remove the characters contained in the following string:
#
# `"&$@[].,'#()-\"!?’_"`
#
# Please ignore the newline (`\n`) character.

# %%
# CODE CELL
words_dict = {}

remove_chars = "&$@[].,'#()-\"!?’_"

# CODE START
new_tweet_texts=[]
for tweet in tweet_texts:
    tweet=tweet.upper()
    for c in remove_chars:
        tweet=tweet.replace(c,"")
    newlist=tweet.split()
    new_tweet_texts.extend(newlist)
for word in new_tweet_texts:
    if not (word in words_dict) and word != "":
        words_dict[word]=new_tweet_texts.count(word)
# CODE END

# Your output should look like this.
print(words_dict)
# Out:
# {'RT': 53, 'WATCHMEJAYJAY:': 1, 'AY': 1, 'DI': 4, 'KA': 4, 'NAKANOOD': 1, 'NG': 14, 'SONA': 65, 'WAG': 2, 'MAGALALA': 1, 'ITO': 1, 'YUNG': 4, 'SUMMARY': 1, 'MGA': 12, 'PLANO': 1, 'NI': 7, 'TATAY': 1, 'LABAN': 1, 'SA': 34, 'COVID': 2, '19:': 1, 'A': 6, 'THREAD': 1, 'TOWERNAMBA:': 2, '【ジェジュン】': 2, '\\カバーアルバムを引っさげたツアー映像🎥/': 1, 'ツアー映像『JJUN': 1, 'LIVE': 1, '2019～LOVE': 1, 'COVERS～』本日入荷しました🙌': 1, '2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤': 1, 'CDがあれば…': 1, 'KAPILKOLOTYA': 1, 'KHARAASONA': 3, 'BHAI': 2, 'JO': 1, 'LE': 1, 'LIYA': 1, 'HAI': 1, 'MENE': 1, '3SAAL': 1, 'PEHLE': 1, 'USKO': 1, 'ME': 3, 'BOYCOTT': 1, 'KR': 1, 'DUGA': 1, 'BUT': 2, 'MUJY': 1, 'MADE': 1, 'IN': 11, 'INDIA': 1, 'IPHONE': 1, 'DEDO': 1, '\\ジェジュンの優しく、深い歌声がしみわたる/': 1, 'カバーアルバム『LOVE': 1, 'COVERS': 2, 'Ⅱ』本日入荷しました🙌': 1, '原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪': 1, '🎁タワレコ特典はアナザージャ…': 1, 'JADINETRASH:': 1, 'HER': 3, 'OWN': 3, 'TIME': 2, 'THOUGHTS': 1, 'STYLE': 1, 'THANK': 1, 'YOU': 4, 'NADINE': 2, 'THE': 55, 'BATTLES': 1, 'FIGHT': 1, 'HAVE': 2, 'ALWAYS': 1, 'BEEN': 1, 'FOR': 11, 'BIGGER…': 1, 'ABSOLUTALBERT:': 1, 'VP': 1, 'ISNT': 1, 'INVITED': 1, 'TO': 36, 'DESIGNATED': 1, 'SURVIVOR': 1, 'CNNPHILIPPINES:': 2, 'THREAD:': 1, 'DUTERTE': 10, 'PUSHED': 1, 'REIMPOSITION': 1, 'OF': 30, 'CAPITAL': 1, 'PUNISHMENT': 1, 'SPECIFYING': 1, 'METHOD': 1, 'LETHAL': 1, 'INJECTION': 1, 'HEINO…': 1, 'QUARKHENARES:': 1, 'WHY': 2, 'DO': 1, 'THEY': 4, 'EVEN': 2, 'GET': 2, 'FILMMAKERS': 1, 'SHOOT': 1, 'FUCKING': 1, 'HASHTAGNIKKO13:': 1, 'KO': 4, 'NAKITA': 2, 'SONA😢😢': 1, 'HAYAAN': 1, 'NA': 19, 'NGA': 1, 'RIN': 4, 'NAMAN': 3, 'NILA': 1, 'TAYO': 2, 'NAKIKITA': 1, 'I': 6, 'HOPE': 1, 'THAT': 7, 'WE': 9, 'CAN': 2, 'SOME': 1, 'OR': 1, 'SAME': 2, 'TREATMENT': 1, 'CLARITY': 1, 'PURPOSE': 1, 'AMP;': 6, 'FASTNESS': 1, 'SUPPORT': 1, 'PASSAGE': 2, 'BAYANIHAN': 2, 'RECOVER': 1, 'AS': 2, 'ONE': 3, 'ACT': 2, 'WHICH': 2, 'WILL': 1, 'SUPPLEMENT': 1, 'FUNDS': 1, 'RECOVERY': 1, 'RESPONSE': 2, 'AGAINST': 2, 'IMPACT': 1, 'COVID19': 7, 'PANDEMIC': 2, 'PRESIDENT': 8, 'DUTERTES': 10, '5TH': 13, 'GMANEWS:': 2, 'PHILIPPINE': 1, 'NEIGHBORS': 1, 'STANDING': 1, 'UP': 5, 'CHINA': 1, 'WITHOUT': 1, 'WAR': 2, 'CARPIO': 1, 'TELLS': 1, 'AFTER': 2, 'HTTPS://TCO/NIEAEXKBCU': 1, 'REAPERSZN': 2, 'STUPID': 1, 'NOMASKERS': 1, 'RUINING': 1, 'FUN': 1, 'EVERYONE': 3, 'ONLINE': 1, 'OFF': 1, '😭😭': 1, 'IAMKARENDAVILA:': 1, 'OKAY': 1, 'CLEARLY': 1, 'SENATOR': 1, 'FRANKLIN': 2, 'DRILON': 2, 'IS': 5, 'PRESIDENTS': 2, 'CONSCIOUSNESS': 1, 'MENTIONING': 1, 'HIM': 3, 'AGAIN': 2, 'CALLS': 1, 'HIM…': 1, 'OUR': 2, 'MARAWI:': 1, 'FAKE': 1, 'NEWS:': 1, 'WALANG': 2, 'HUMAN': 2, 'RIGHTS': 2, 'VIOLATION': 1, 'MARTIAL': 1, 'LAW': 2, 'SABI': 2, 'NYA': 1, 'KANYANG': 2, 'HTTPS://TCO/YDT5A7F6KI': 1, 'THISISOURMINDANAO': 1, 'JOSEPHMORONG:': 1, 'TADAH': 1, 'HIGHLIGHTS': 1, 'PRES': 4, 'GMANEWS': 1, 'HTTPS://TCO/BC4VFGYRPQ': 1, 'MARVSMODEL': 1, 'MALIBAN': 1, 'SILA': 3, 'VICE': 1, 'NASA': 1, 'PALA': 2, 'SIYA': 2, '😁': 1, 'SERAHPHYMN': 1, 'TOTALLY': 2, '5': 2, '🥺': 1, 'IF': 3, 'MY': 8, 'MET': 1, 'WOULD': 3, 'VIBE': 1, 'FAHMIRAZA1RAZA': 1, 'AJMALJAMI': 1, 'KACHRA': 2, 'DUMPING': 1, 'NAME': 1, 'HY': 1, 'KBHI': 1, 'PAIDA': 1, 'HONA': 1, 'HA': 2, 'GVT': 1, 'OSKO': 1, 'DISPOSE': 1, 'KRNA': 1, 'JAB': 1, 'HOGA': 2, 'YA': 4, 'LOG': 1, 'KAHAN': 1, 'DUMPKRY': 1, 'BATAO': 1, 'HMVKAWASAKI:': 1, '【ジェジュン】大ヒットしたカバーアルバムの第2弾「LOVE': 1, 'II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「JJUN': 1, 'LIVE…': 1, 'RAPPLERDOTCOM:': 3, 'MESSAGE': 2, 'SEEMS': 1, 'CLEAR:': 1, 'SMART': 1, 'AND': 14, 'GLOBE': 3, 'GO': 1, 'WAY': 4, 'ABSCBN': 1, 'CANNOT': 1, 'CLEAR': 2, 'CREATIVE': 1, 'LEGAL': 1, 'HURDLES': 1, 'WIL…': 1, 'EVANU': 1, 'THALA': 1, 'KAGA': 1, 'VARALA': 1, 'ELAN': 1, 'FC': 2, 'PAGE': 2, 'KU': 2, 'THA': 3, 'FANS': 2, 'ERKANGA': 1, 'YARU': 1, 'TAG': 5, 'ENADA': 1, 'KIRUIU': 1, 'KO🔥GALA': 1, 'VALIMAI': 2, 'THALAAJITH': 2, 'AJITHKUMAR': 2, 'HTTPS://TCO/HQ14YGO6LU': 1, 'LIST:': 1, '21': 2, 'PRIORITY': 1, 'BILLS': 2, '2020': 7, '|': 2, 'BY': 1, 'MARACEPEDA': 2, 'HTTPS://TCO/CSIWT ...

# %% [markdown]
# ### 1.5
#
# Now, we would like to have a list of words and counts sorted by count in descending order.
#
# Define a new list variable named `words_list` containing **tuples**, where each tuple is as follows:
#
# `(word, count)`
#
# Print the contents of `words_list`.
#
# Sample output is provided below.

# %%
# CODE CELL
words_list = []
# CODE START
for item in words_dict.items():
    words_list.append(item)
print(words_list)
# CODE END

# The output should look like this. 
#print(words_list)
# Out:
# [('RT', 53), ('WATCHMEJAYJAY:', 1), ('AY', 1), ('DI', 4), ('KA', 4), ('NAKANOOD', 1), ('NG', 14), ('SONA', 65), ('WAG', 2), ('MAGALALA', 1), ('ITO', 1), ('YUNG', 4), ('SUMMARY', 1), ('MGA', 12), ('PLANO', 1), ('NI', 7), ('TATAY', 1), ('LABAN', 1), ('SA', 34), ('COVID', 2), ('19:', 1), ('A', 6), ('THREAD', 1), ('TOWERNAMBA:', 2), ('【ジェジュン】', 2), ('\\カバーアルバムを引っさげたツアー映像🎥/', 1), ('ツアー映像『JJUN', 1), ('LIVE', 1), ('2019～LOVE', 1), ('COVERS～』本日入荷しました🙌', 1), ('2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤', 1), ('CDがあれば…', 1), ('KAPILKOLOTYA', 1), ('KHARAASONA', 3), ('BHAI', 2), ('JO', 1), ('LE', 1), ('LIYA', 1), ('HAI', 1), ('MENE', 1), ('3SAAL', 1), ('PEHLE', 1), ('USKO', 1), ('ME', 3), ('BOYCOTT', 1), ('KR', 1), ('DUGA', 1), ('BUT', 2), ('MUJY', 1), ('MADE', 1), ('IN', 11), ('INDIA', 1), ('IPHONE', 1), ('DEDO', 1), ('\\ジェジュンの優しく、深い歌声がしみわたる/', 1), ('カバーアルバム『LOVE', 1), ('COVERS', 2), ('Ⅱ』本日入荷しました🙌', 1), ('原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪', 1), ('🎁タワレコ特典はアナザージャ…', 1), ('JADINETRASH:', 1), ('HER', 3), ('OWN', 3), ('TIME', 2), ('THOUGHTS', 1), ('STYLE', 1), ('THANK', 1), ('YOU', 4), ('NADINE', 2), ('THE', 55), ('BATTLES', 1), ('FIGHT', 1), ('HAVE', 2), ('ALWAYS', 1), ('BEEN', 1), ('FOR', 11), ('BIGGER…', 1), ('ABSOLUTALBERT:', 1), ('VP', 1), ('ISNT', 1), ('INVITED', 1), ('TO', 36), ('DESIGNATED', 1), ('SURVIVOR', 1), ('CNNPHILIPPINES:', 2), ('THREAD:', 1), ('DUTERTE', 10), ('PUSHED', 1), ('REIMPOSITION', 1), ('OF', 30), ('CAPITAL', 1), ('PUNISHMENT', 1), ('SPECIFYING', 1), ('METHOD', 1), ('LETHAL', 1), ('INJECTION', 1), ('HEINO…', 1), ('QUARKHENARES:', 1), ('WHY', 2), ('DO', 1), ('THEY', 4), ('EVEN', 2), ('GET', 2), ('FILMMAKERS', 1), ('SHOOT', 1), ('FUCKING', 1), ('HASHTAGNIKKO13:', 1), ('KO', 4), ('NAKITA', 2), ('SONA😢😢', 1), ('HAYAAN', 1), ('NA', 19), ('NGA', 1), ('RIN', 4), ('NAMAN', 3), ('NILA', 1), ('TAYO', 2), ('NAKIKITA', 1), ('I', 6), ('HOPE', 1), ('THAT', 7), ('WE', 9), ('CAN', 2), ('SOME', 1), ('OR', 1), ('SAME', 2), ('TREATMENT', 1), ('CLARITY', 1), ('PURPOSE', 1), ('AMP;', 6), ('FASTNESS', 1), ('SUPPORT', 1), ('PASSAGE', 2), ('BAYANIHAN', 2), ('RECOVER', 1), ('AS', 2), ('ONE', 3), ('ACT', 2), ('WHICH', 2), ('WILL', 1), ('SUPPLEMENT', 1), ('FUNDS', 1), ('RECOVERY', 1), ('RESPONSE', 2), ('AGAINST', 2), ('IMPACT', 1), ('COVID19', 7), ('PANDEMIC', 2), ('PRESIDENT', 8), ('DUTERTES', 10), ('5TH', 13), ('GMANEWS:', 2), ('PHILIPPINE', 1), ('NEIGHBORS', 1), ('STANDING', 1), ('UP', 5), ('CHINA', 1), ('WITHOUT', 1), ('WAR', 2), ('CARPIO', 1), ('TELLS', 1), ('AFTER', 2), ('HTTPS://TCO/NIEAEXKBCU', 1), ('REAPERSZN', 2), ('STUPID', 1), ('NOMASKERS', 1), ('RUINING', 1), ('FUN', 1), ('EVERYONE', 3), ('ONLINE', 1), ('OFF', 1), ('😭😭', 1), ('IAMKARENDAVILA:', 1), ('OKAY', 1), ('CLEARLY', 1), ('SENATOR', 1), ('FRANKLIN', 2), ('DRILON', 2), ('IS', 5), ('PRESIDENTS', 2), ('CONSCIOUSNESS', 1), ('MENTIONING', 1), ('HIM', 3), ('AGAIN', 2), ('CALLS', 1), ('HIM…', 1), ('OUR', 2), ('MARAWI:', 1), ('FAKE', 1), ('NEWS:', 1), ('WALANG', 2), ('HUMAN', 2), ('RIGHTS', 2), ('VIOLATION', 1), ('MARTIAL', 1), ('LAW', 2), ('SABI', 2), ('NYA', 1), ('KANYANG', 2), ('HTTPS://TCO/YDT5A7F6KI', 1), ('THISISOURMINDANAO', 1), ('JOSEPHMORONG:', 1), ('TADAH', 1), ('HIGHLIGHTS', 1), ('PRES', 4), ('GMANEWS', 1), ('HTTPS://TCO/BC4VFGYRPQ', 1), ('MARVSMODEL', 1), ('MALIBAN', 1), ('SILA', 3), ('VICE', 1), ('NASA', 1), ('PALA', 2), ('SIYA', 2), ('😁', 1), ('SERAHPHYMN', 1), ('TOTALLY', 2), ('5', 2), ('🥺', 1), ('IF', 3), ('MY', 8), ('MET', 1), ('WOULD', 3), ('VIBE', 1), ('FAHMIRAZA1RAZA', 1), ('AJMALJAMI', 1), ('KACHRA', 2), ('DUMPING', 1), ('NAME', 1), ('HY', 1), ('KBHI', 1), ('PAIDA', 1), ('HONA', 1), ('HA', 2), ('GVT', 1), ('OSKO', 1), ('DISPOSE', 1), ('KRNA', 1), ('JAB', 1), ('HOGA', 2), ('YA', 4), ('LOG', 1), ('KAHAN', 1), ('DUMPKRY', 1), ('BATAO', 1), ('HMVKAWASAKI:', 1), ('【ジェジュン】大ヒットしたカバーアルバムの第2弾「LOVE', 1), ('II」入荷しました✨CDの2形態には先着ご購入特典で「アナザージャケット（HMV絵柄）」をお付けしています🌹プレミアムライブを収録した映像作品「JJUN', 1), ('LIVE…', 1), ('RAPPLERDOTCOM:', 3), ('MESSAGE', 2), ('SEEMS', 1), ('CLEAR:', 1), ('SMART', ...

# %% [markdown]
# ### 1.6
#
# Sort the list by count (which is the second element of each tuple) in descending (or reverse) order.
#
# Print the contents of the newly-sorted list `words_list`.
#
# Sample output shown below.

# %%
# CODE CELL

# CODE START
def criteria(tup):
    return tup[1]
words_list.sort(reverse=True, key = criteria) 
#https://www.w3schools.com/python/ref_list_sort.asp
# CODE END

# The output should look like this.
print(words_list)
# Out:
# [('SONA', 65), ('THE', 55), ('RT', 53), ('TO', 36), ('SA', 34), ('OF', 30), ('ANG', 20), ('NA', 19), ('NG', 14), ('AND', 14), ('5TH', 13), ('MGA', 12), ('IN', 11), ('FOR', 11), ('DUTERTE', 10), ('DUTERTES', 10), ('WE', 9), ('PRESIDENT', 8), ('MY', 8), ('WITH', 8), ('NI', 7), ('THAT', 7), ('COVID19', 7), ('2020', 7), ('THIS', 7), ('A', 6), ('I', 6), ('AMP;', 6), ('MAY', 6), ('UP', 5), ('IS', 5), ('TAG', 5), ('ON', 5), ('HIS', 5), ('PA', 5), ('DI', 4), ('KA', 4), ('YUNG', 4), ('YOU', 4), ('THEY', 4), ('KO', 4), ('RIN', 4), ('PRES', 4), ('YA', 4), ('WAY', 4), ('RODRIGO', 4), ('ROA', 4), ('STATE', 4), ('SONA2020', 4), ('FIRST', 4), ('SI', 4), ('STUDENT', 4), ('KHARAASONA', 3), ('ME', 3), ('HER', 3), ('OWN', 3), ('NAMAN', 3), ('ONE', 3), ('EVERYONE', 3), ('HIM', 3), ('SILA', 3), ('IF', 3), ('WOULD', 3), ('RAPPLERDOTCOM:', 3), ('GLOBE', 3), ('THA', 3), ('LIKE', 3), ('CONGRESS', 3), ('BEFORE', 3), ('FROM', 3), ('AT', 3), ('LANG', 3), ('ITS', 3), ('DAPAT', 3), ('SONAGKAISA', 3), ('DURING', 3), ('ARAW', 3), ('COUNCIL', 3), ('PRESS', 3), ('WAG', 2), ('COVID', 2), ('TOWERNAMBA:', 2), ('【ジェジュン】', 2), ('BHAI', 2), ('BUT', 2), ('COVERS', 2), ('TIME', 2), ('NADINE', 2), ('HAVE', 2), ('CNNPHILIPPINES:', 2), ('WHY', 2), ('EVEN', 2), ('GET', 2), ('NAKITA', 2), ('TAYO', 2), ('CAN', 2), ('SAME', 2), ('PASSAGE', 2), ('BAYANIHAN', 2), ('AS', 2), ('ACT', 2), ('WHICH', 2), ('RESPONSE', 2), ('AGAINST', 2), ('PANDEMIC', 2), ('GMANEWS:', 2), ('WAR', 2), ('AFTER', 2), ('REAPERSZN', 2), ('FRANKLIN', 2), ('DRILON', 2), ('PRESIDENTS', 2), ('AGAIN', 2), ('OUR', 2), ('WALANG', 2), ('HUMAN', 2), ('RIGHTS', 2), ('LAW', 2), ('SABI', 2), ('KANYANG', 2), ('PALA', 2), ('SIYA', 2), ('TOTALLY', 2), ('5', 2), ('KACHRA', 2), ('HA', 2), ('HOGA', 2), ('MESSAGE', 2), ('CLEAR', 2), ('FC', 2), ('PAGE', 2), ('KU', 2), ('FANS', 2), ('VALIMAI', 2), ('THALAAJITH', 2), ('AJITHKUMAR', 2), ('21', 2), ('BILLS', 2), ('|', 2), ('MARACEPEDA', 2), ('KATRINADOMINGO', 2), ('WONT', 2), ('REACH', 2), ('NATION', 2), ('ONLY', 2), ('HERE', 2), ('LA', 2), ('PERSONA', 2), ('QUE', 2), ('NO', 2), ('TE', 2), ('LOOK:', 2), ('HEALTH', 2), ('DILIMAN', 2), ('BE', 2), ('TWEET', 2), ('F…', 2), ('STEP', 2), ('KAR', 2), ('HE', 2), ('MUJHE', 2), ('UPDATE', 2), ('GIVE', 2), ('DISCUSSIONS', 2), ('RELATED', 2), ('HELD', 2), ('EARLIER', 2), ('AFTERNOON', 2), ('REQUEST', 2), ('SHARES', 2), ('TAYONG', 2), ('WAS', 2), ('GROUPS', 2), ('PROTEST', 2), ('AKO', 2), ('ABOUT', 2), ('NANGA', 2), ('THALAAJITHFC', 2), ('GOVERNMENTS', 2), ('YOUR', 2), ('MABUTI', 2), ('HINDI', 2), ('KUNG', 2), ('SAAN', 2), ('PROTESTA', 2), ('REACT', 2), ('PLEASE', 2), ('ANCALERTS:', 2), ('SENATE', 2), ('LEADER', 2), ('SAID', 2), ('TAPOS', 2), ('PANGULO', 2), ('ALSO', 2), ('PROVIDED', 2), ('THROUGH', 2), ('WERE', 2), ('NGAYONG', 2), ('WHAT', 2), ('BA', 2), ('DONT', 2), ('PARA', 2), ('OFWS', 2), ('MATAPOS', 2), ('POSTSONA', 2), ('NEW', 2), ('EXECUTIVE', 2), ('ZUBIRI', 2), ('TEST', 2), ('PERO', 2), ('WAKASONA2020', 2), ('WATCHMEJAYJAY:', 1), ('AY', 1), ('NAKANOOD', 1), ('MAGALALA', 1), ('ITO', 1), ('SUMMARY', 1), ('PLANO', 1), ('TATAY', 1), ('LABAN', 1), ('19:', 1), ('THREAD', 1), ('\\カバーアルバムを引っさげたツアー映像🎥/', 1), ('ツアー映像『JJUN', 1), ('LIVE', 1), ('2019～LOVE', 1), ('COVERS～』本日入荷しました🙌', 1), ('2日間のみのプレミアムライヴを映像とCDでお楽しみいただける豪華盤', 1), ('CDがあれば…', 1), ('KAPILKOLOTYA', 1), ('JO', 1), ('LE', 1), ('LIYA', 1), ('HAI', 1), ('MENE', 1), ('3SAAL', 1), ('PEHLE', 1), ('USKO', 1), ('BOYCOTT', 1), ('KR', 1), ('DUGA', 1), ('MUJY', 1), ('MADE', 1), ('INDIA', 1), ('IPHONE', 1), ('DEDO', 1), ('\\ジェジュンの優しく、深い歌声がしみわたる/', 1), ('カバーアルバム『LOVE', 1), ('Ⅱ』本日入荷しました🙌', 1), ('原曲の良さをひきたてるだけでなく、ジェジュンらしさも全開のアルバムです♪', 1), ('🎁タワレコ特典はアナザージャ…', 1), ('JADINETRASH:', 1), ('THOUGHTS', 1), ('STYLE', 1), ('THANK', 1), ('BATTLES', 1), ('FIGHT', 1), ('ALWAYS', 1), ('BEEN', 1), ('BIGGER…', 1), ('ABSOLUTALBERT:', 1), ('VP', 1), ('ISNT', 1), ('INVITED', 1), ('DESIGNATED', 1), ('SURVIVOR', 1), ('THREAD:', 1), ('PUSHED', 1), ('REIMPOSITION', 1), ('CAPITAL', 1), ('PUNISHMENT', 1), ('SPECIFYING', 1) ...

# %% [markdown]
# ### 1.7
#
# Print out the top 5 words (based on count).
#
# Take note of the formatting below (i.e. one line per print output).
#
# Sample output shown below.

# %%
# CODE CELL

# CODE START
for i in range(5):
    print(str(i+1) + " " + str(words_list[i]))
# CODE END

# The output should look like this.
# Out:
# 1 ('SONA', 65)
# 2 ('THE', 55)
# 3 ('RT', 53)
# 4 ('TO', 36)
# 5 ('SA', 34)

# %% [markdown]
# ### 1.8
#
# Write a new csv file `./output/wordcount.csv` with format like so:
#
# `word,count`
# `SONA,65`
# `THE,55`
# `RT,53`
# `TO,36`
# `SA,34`
# `...`

# %%
# CODE CELL
import csv
import json

# CODE START
#https://docs.python.org/3/library/csv.html
with open('./output/wordcount.csv', 'w', newline='') as csvfile:
    fieldnames = ['word', 'count']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for word in words_list:
        #print(word)
        writer.writerow({'word': word[0], 'count': word[1]})
# CODE END

# %% [markdown]
# Perform a `diff` or `fc` operation between your output file and the file named `wordcount-test.csv` which should be included in `section1`. Make sure there are no differences.
#
# **IMPORTANT**: Please make sure that you submit wordcount.csv along with the rest of your files.

# %% [markdown]
# ## Section 2: Reports for the Registrar (55 points)

# %% [markdown]
# ### Context
#
# Data is rarely in the form in which you want it. In this section of the assessment, you are doing consulting work for Ateneo's Office of the Registrar. They managed to collect the enlistment data for 4410 students through a Google Form. The form was not designed in such a way that the collected data is immediately usable, so they hired you to process their raw data into more appropriate forms.
#
# Please run the following cell to load the file.

# %%
# execute this cell to load the file
import json

file_path = './section2/student-enrollment-data.json'

with open(file_path, 'r') as f:
    student_data = json.load(f)
    
# Print the first few items of this file to check that it worked properly
# Please infer and understand the schema of this file.
print(student_data[:3])
# Out:
# [{'enlistment': [{'course code': 'UK 60', 'section': 'A'}, {'course code': 'GF 24', 'section': 'B'}, {'course code': 'ME 40', 'section': 'B'}, {'course code': 'VY 44', 'section': 'D'}, {'course code': 'EN 94', 'section': 'B'}], 'id': '201001', 'paid': True, 'school': 'SOSE', 'year level': 2}, {'enlistment': [{'course code': 'EQ 61', 'section': 'D'}, {'course code': 'UZ 22', 'section': 'B'}, {'course code': 'KS 36', 'section': 'B'}, {'course code': 'VH 63', 'section': 'A'}, {'course code': 'IW 81', 'section': 'C'}], 'id': '211002', 'paid': True, 'school': 'JGSOM', 'year level': 1}, {'enlistment': [{'course code': 'WE 15', 'section': 'D'}, {'course code': 'ZP 68', 'section': 'A'}, {'course code': 'GI 78', 'section': 'A'}, {'course code': 'GK 72', 'section': 'C'}, {'course code': 'FA 24', 'section': 'D'}, {'course code': 'UJ 28', 'section': 'A'}], 'id': '201003', 'paid': True, 'school': 'JGSOM', 'year level': 2}]

# %% [markdown]
# ### 2.1
#
# The first report the Registrar needs is a summary of all courses being offered. They want this report in the form of a **dictionary** whose keys are unique course codes and whose values are dictionaries with a single key-value pair describing the sections available for that course code.
#
# Here is the schema of the desired output:
#
# `{`
# &nbsp;&nbsp;&nbsp;&nbsp;`course_code: {`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"sections": [sections]`
# &nbsp;&nbsp;&nbsp;&nbsp;`}`
# `}`
#
# A dictionary called `courses` is provided to you in the following cell. Using `student_data`, populate `courses` with the data the Registrar needs.
#
# Dump this file as `./output/courses-output.json`.
#
# Additional specifications:
# 1. Sort the list of sections alphabetically.
#
# Sample output is provided in `./section2/courses-sample-output.json`.

# %%
# CODE CELL
import json
courses = {}

# CODE START
for data in student_data:
    #print("data: ", data)
    for course in data["enlistment"]:
        #print("course: ", course)
        #print("course[course]: ", course["course code"])
        #nts: courses.get(course["course code"]) and courses[course["course code"]] return the same value for key "course code"
        #but .get() returns 'None' if there is no existing value 
        #courses[course["course code"]] results in an error if there is no existing value
        
        if courses.get(course["course code"]) == None:

            sec_list = []
            sec_list.append(course["section"])
            sec_list.sort()
            sec_dict = {}
            sec_dict["sections"] = sec_list
            courses[course["course code"]] = sec_dict
            #print("courses: ", courses)
        else:
            existing_course_code_sec_dict = courses[course["course code"]]

            sec_list = existing_course_code_sec_dict["sections"]
            if course["section"] not in sec_list:
                sec_list.append(course["section"])
            sec_list.sort()
         
f = open("./output/courses-output.json", "w")
f.write(str(courses))
f.close()
# CODE END

# The output should look like this.
print(courses)
# Out:
# {'UK 60': {'sections': ['A']}, 'GF 24': {'sections': ['A', 'B', 'C']}, 'ME 40': {'sections': ['A', 'B', 'C']}, 'VY 44': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'EN 94': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'EQ 61': {'sections': ['A', 'B', 'C', 'D']}, 'UZ 22': {'sections': ['A', 'B', 'C']}, 'KS 36': {'sections': ['A', 'B', 'C']}, 'VH 63': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'IW 81': {'sections': ['A', 'B', 'C']}, 'WE 15': {'sections': ['A', 'B', 'C', 'D']}, 'ZP 68': {'sections': ['A']}, 'GI 78': {'sections': ['A']}, 'GK 72': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'FA 24': {'sections': ['A', 'B', 'C', 'D']}, 'UJ 28': {'sections': ['A', 'B', 'C']}, 'ZJ 82': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'SN 88': {'sections': ['A']}, 'TT 59': {'sections': ['A', 'B']}, 'HK 84': {'sections': ['A']}, 'HW 19': {'sections': ['A']}, 'SE 79': {'sections': ['A', 'B', 'C', 'D']}, 'BN 85': {'sections': ['A', 'B', 'C', 'D', 'E', 'F']}, 'LV 41': {'sections': ['A', 'B', 'C', 'D']}, 'OG 37': {'sections': ['A', 'B', 'C', 'D']}, 'QR 51': {'sections': ['A']}, 'TS 66': {'sections': ['A']}, 'YB 54': {'sections': ['A', 'B', 'C', 'D']}, 'YD 55': {'sections': ['A', 'B', 'C', 'D']}, 'VC 62': {'sections': ['A', 'B', 'C']}, 'FX 96': {'sections': ['A']}, 'GM 72': {'sections': ['A']}, 'GV 12': {'sections': ['A']}, 'YS 74': {'sections': ['A', 'B', 'C']}, 'MU 79': {'sections': ['A', 'B']}, 'VS 18': {'sections': ['A']}, 'AI 41': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'MC 25': {'sections': ['A', 'B']}, 'FZ 18': {'sections': ['A']}, 'YQ 49': {'sections': ['A', 'B']}, 'AX 43': {'sections': ['A']}, 'KC 22': {'sections': ['A', 'B', 'C', 'D']}, 'KD 10': {'sections': ['A', 'B', 'C']}, 'RT 81': {'sections': ['A']}, 'UK 70': {'sections': ['A', 'B', 'C', 'D', 'E']}, 'LJ 29': {'sections': ['A', 'B']}, 'PG 71': {'sections': ['A', 'B', 'C']}, 'KD 33': {'sections': ['A']}, 'ZB 82': {'sections': ['A']}}

# %% [markdown]
# ### 2.2
#
# The second report the Registrar needs is a _class list_ of every section. They want this report in the form of a **dictionary** whose keys are the course code and whose values are dictionaries describing the sections of that course code. Each section dictionary has two key-value pairs:
# 1. Key: "section"; Value: Section letter
# 2. Key: "class list"; Value: [id numbers]
#
# Here is the schema of the desired output:
# `{`
# &nbsp;&nbsp;&nbsp;&nbsp;`course_code: [{`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"section": section_letter,`
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;`"class list": [id_numbers]`
# &nbsp;&nbsp;&nbsp;&nbsp;`}]`
# `}`
#
# A dictionary called `class_lists` is provided to you. Using `student_data`, populate `class_lists` with the data that the Registrar needs.
#
# Dump this file as `./output/class-lists.json`.
#
# Additional specifications:
# 1. Sort the list of ID numbers. No need to convert them to int, just sort them in place with `.sort()`.
# 2. Do not reference the `courses` dictionary from Item 2.1 directly. This cell should be able to run independently of Item 2.1. You may, however, reuse your code by copy-pasting it here if you find that it will help.
#
# Sample output is provided in `./section2/class-lists-sample-output.json`.

# %%
# CODE CELL
import json
class_lists = {}

# CODE START
for data in student_data:
#print(data["enlistment"])
    for course in data["enlistment"]:
        if class_lists.get(course["course code"]) == None:
            class_list = []
            section_class_dict = {}
            section_class_list = []
            class_list.append(data["id"])
            section_class_dict["section"] = course["section"]
            section_class_dict["class list"] = class_list
            section_class_list.append(section_class_dict)
            #print("section_class_list = ", section_class_list)
            class_lists[course["course code"]] = section_class_list
            #print("class_lists = ", class_lists)
        else:
            existing_course_code_section_list = class_lists[course["course code"]]
            #if course["course code"] == "VY 44":
                #print(course["course code"])
                #print("existing_course_code_section_list: ", existing_course_code_section_list)
            #print("len existing_course_code_section_list: ", len(existing_course_code_section_list))
            section_list_length = len(existing_course_code_section_list)
            #print("length = ", section_list_length)
            #new_section_class_dict = {}
            for index in range(section_list_length):
                #print("index = ", index)
                section_class_dict = existing_course_code_section_list[index]
                #if course["course code"] == "VY 44":
                    #print(course["course code"], " section: ", course["section"])
                    #print("section_class_dict", section_class_dict)
                if section_class_dict["section"] == course["section"]:
                    #if course["course code"] == "VY 44":
                        #print("IN IF")
                    #print(course["course code"], " section: ", course["section"])
                    #print("section_class_dict:class_list = ", section_class_dict["class list"])
                    section_class_dict["class list"].append(data["id"])
                    section_class_dict["class list"].sort()
                    #if course["course code"] == "VY 44":
                        #print("section_class_dict", section_class_dict)
                    break
                elif index == section_list_length - 1:
                    #if course["course code"] == "VY 44":
                        #print("IN ELSE")
                    new_class_list = []
                    new_section_class_dict = {}
                    new_class_list.append(data["id"])
                    new_section_class_dict["section"] = course["section"]
                    new_section_class_dict["class list"] = new_class_list
                    #if course["course code"] == "VY 44":
                        #print("ELSE new_section_class_dict = ", new_section_class_dict)
                    existing_course_code_section_list.append(new_section_class_dict) 
                    #if course["course code"] == "VY 44":
                        #print("ELSE existing_course_code_section_list = ", existing_course_code_section_list)
 
                    
            '''
            existing_course_code_section_list = class_lists[course["course code"]]
            #print("existing_course_code_section_list: ", existing_course_code_section_list)
            #print("len existing_course_code_section_list: ", len(existing_course_code_section_list))
            section_list_length = len(existing_course_code_section_list)
            #print("length = ", section_list_length)
            new_section_class_dict = {}
            for index in range(section_list_length):
                #print("index = ", index)
                section_class_dict = existing_course_code_section_list[index]
                #print(course["course code"], " section: ", course["section"])
                #print("section_class_dict", section_class_dict)
                if section_class_dict["section"] == course["section"]:
                    #print(course["course code"], " section: ", course["section"])
                    #print("section_class_dict:class_list = ", section_class_dict["class list"])
                    section_class_dict["class list"].append(data["id"])
                    section_class_dict["class list"].sort()
                else:
                    new_class_list = []
                    
                    new_class_list.append(data["id"])
                    new_section_class_dict["section"] = course["section"]
                    new_section_class_dict["class list"] = new_class_list
                   

            if len(new_section_class_dict) > 0:
                existing_course_code_section_list.append(new_section_class_dict)
            '''    
'''
rem: why it needs the last line
{
    course_code: [{
        "section": section_letter,
        "class list": [id_numbers]
    },
    {}]
}
'''

f = open("./output/class-lists.json", "w")
f.write(str(class_lists))
f.close()
# CODE END

# The output should look like this.
# This code is not supposed to be able to run in your notebook; it is fine to remove it if you will begin working.

# %% [markdown]
# ## Section 3: Payroll (65 points)

# %% [markdown]
# ### Context
#
# A startup decides to avoid hiring regular employees for now. Instead, they have been engaging consultants and interns to support them in their current operations. There are not a lot of people, but preparation is tedious.
#
# All consultants and interns get paid at the end of the month.
#
# Interns are expected to render 20 hours of work each month. The actual number of hours worked by each intern is then prorated against the monthly fee stated in their contract. For example, if an intern works 20 hours, then the disbursement will be 100%. If another intern works for only 11, the payout will be 11/20 or 55%.
#
# If interns go overtime in the month, they get a premium of 200% on their hourly rate for anything in excess of 20 hours. The hourly rate is computed as follows:
#
# *hourly rate = contracted monthly fee / 20*
#
# The startup works on an honesty system. In lieu of timesheets, each intern is given a link to Google Forms where they specify their temporary company ID and the number of hours they rendered for the month. All entries are then logged in an associated Google Sheets document. Human Resources then is able to export the spreadsheet into a CSV that looks like so (for the month of July, 2021, as contained in the file **./section3/interns-timelog-july-2021.csv**):
#
# ```
# id,hours_rendered
# 2021001,20
# 2021002,17
# 2021003,16
# 2021004,15
# 2021005,16
# 2021006,18
# 2021007,17
# 2021008,17
# 2021009,15
# 2021010,18
# 2021011,16
# 2021012,20
# 2021013,18
# 2021014,22
# 2021015,20
# 2021016,25
# 2021017,20
# 2021018,17
# 2021019,20
# 2021020,18
# ```
#
# At the company's discretion, certain employees are given work-from-home (WFH) privileges. If an intern has been tagged to be given a WFH allowance, an additional P300 is given.
#
# In addition, the intern gets to designate one of two banks (BPI, BDO) for payroll crediting.
#
# The intern masterfile, saved from a central database as csv, is shown below:
#
# ```
# id,bank,account_number,monthly_fee,wfh
# 2021001,BPI,1093 5000 5001,4500,Y
# 2021002,BPI,1093 5000 5002,3500,Y
# 2021003,BPI,1093 5000 5003,4500,Y
# 2021004,BPI,1093 5000 5004,4500,Y
# 2021005,BPI,1093 5000 5005,6000,Y
# 2021006,BPI,1093 5000 5006,4500,Y
# 2021007,BPI,1093 5000 5007,5000,Y
# 2021008,BPI,1093 5000 5008,4500,Y
# 2021009,BPI,1093 5000 5009,4500,N
# 2021010,BPI,1093 5000 5010,6000,N
# 2021011,BPI,1093 5000 5011,4500,N
# 2021012,BPI,1093 5000 5012,3500,N
# 2021013,BPI,1093 5000 5013,4500,N
# 2021014,BPI,1093 5000 5014,4500,N
# 2021015,BPI,1093 5000 5015,5000,Y
# 2021016,BPI,1093 5000 5016,4500,Y
# 2021017,BPI,1093 5000 5017,6000,Y
# 2021018,BPI,1093 5000 5018,3500,Y
# 2021019,BPI,1093 5000 5019,4500,Y
# 2021020,BPI,1093 5000 5020,4500,Y
# ```
#
# Consultants are paid in full (with no accounting for time); however, their take home pay is their contracted monthly fee less 10%. For example, if one consultant's gross pay is P100,000, the amount to be disbursed is P100,000 less 10% = P90,000. For another consultant that insists on P100,000 as net amount, it will be the company's burden to shoulder the taxes; this arrangement is commonly known as "grossing up". In the case of gross-up, if the disbursement needs to preserve P100,000.00, the contracted monthly fee is P111,111.11.
#
# Similar to interns, certain consultants are provided WFH allowance.
#
# The consultant masterlist is shown below:
#
# ```
# tin,bank,account_number,monthly_fee,wfh
# 151-500-200-000,BPI,1093 5000 6001,100000,Y
# 151-500-201-000,BPI,1093 5000 6002,50000,Y
# 151-500-202-000,BDO,0078 0000 0001,111111.11,Y
# 151-500-203-000,BPI,1093 5000 6004,100000,Y
# 151-500-204-000,BPI,1093 5000 6005,65000,Y
# 151-500-205-000,BPI,1093 5000 6006,130000,Y
# 151-500-206-000,BDO,0078 0000 0002,50000,Y
# 151-500-207-000,BDO,0078 0000 0003,45000,Y
# 151-500-208-000,BPI,1093 5000 6007,45000,N
# 151-500-209-000,BPI,1093 5000 6008,60000,N
# 151-500-210-000,BPI,1093 5000 6009,45000,N
# ```

# %% [markdown]
# ### 3.1

# %% [markdown]
# #### 3.1.1
#
# Write a function **get_utilization** with an argument **hours_rendered** and returns utilization (not percentage).

# %%
# CODE CELL

# CODE START
def get_utilization(hours_rendered):
    return float(int(hours_rendered)/20)

# CODE END

# %% [markdown]
# #### 3.1.2
#
# Write a function **get_pay** with four arguments: **monthly_fee**, **hours_rendered**, **overtime**, and **wfh_allowance**. It then returns the computed takehome pay as float.
#
# This function will presumably call **get_utilization**.

# %%
# CODE CELL

# CODE START
def get_pay(monthly_fee, hours_rendered, overtime_pay, wfh_allowance):
    pay = 0
    if int(hours_rendered) > 20:
        pay = float(monthly_fee) + float(overtime_pay) + float(wfh_allowance)
    else:
        pay = float(monthly_fee) * float(get_utilization(int(hours_rendered))) + float(wfh_allowance)

    return float(pay)
# CODE END

# %% [markdown]
# #### 3.1.3
#
# Write a function **get_overtime_pay** that accepts **hours_rendered** and **monthly_fee** as parameters and then returns the amount of overtime to credit to the intern.

# %%
# CODE CELL

# CODE START
def get_overtime_pay(monthly_fee,hours_rendered):
    if int(hours_rendered) > 20:
        hourly_rate = float(monthly_fee) / 20
        overtime_rate = hourly_rate * (int(hours_rendered) - 20) * 2
        return overtime_rate
    else:
        return 0.0
# CODE END

# %% [markdown]
# You may run the cell below to test your code.

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it!

# Expected output: 2250.0
get_overtime_pay(4500,25)
# Out:
# 2250.0

# %% [markdown]
# ### 3.2: For Interns

# %% [markdown]
# #### 3.2.1
#
# Create a list variable named `raw_log` that contains dictionaries (or ordered dictionaries if you use the DictReader method of the Python csv module) for each entry in the time-and-attendance log file **./section3/interns-timelogs-july2021.csv**.

# %%
# CODE CELL
import csv
raw_log = []
# CODE START
with open("./section3/interns-timelogs-july2021.csv", newline='') as csvfile:
        reader = csv.DictReader(csvfile)
        for row in reader:
            raw_log.append(row)
            
#print(raw_log)
#https://docs.python.org/3/library/csv.html
# CODE END

# sample dump of raw_log in interactive mode
raw_log
# Out:
# [{'id': '2021001', 'hours_rendered': '20'},
#  {'id': '2021002', 'hours_rendered': '17'},
#  {'id': '2021003', 'hours_rendered': '16'},
#  {'id': '2021004', 'hours_rendered': '15'},
#  {'id': '2021005', 'hours_rendered': '16'},
#  {'id': '2021006', 'hours_rendered': '18'},
#  {'id': '2021007', 'hours_rendered': '17'},
#  {'id': '2021008', 'hours_rendered': '17'},
#  {'id': '2021009', 'hours_rendered': '15'},
#  {'id': '2021010', 'hours_rendered': '18'},
#  {'id': '2021011', 'hours_rendered': '16'},
#  {'id': '2021012', 'hours_rendered': '20'},
#  {'id': '2021013', 'hours_rendered': '18'},
#  {'id': '2021014', 'hours_rendered': '22'},
#  {'id': '2021015', 'hours_rendered': '20'},
#  {'id': '2021016', 'hours_rendered': '25'},
#  {'id': '2021017', 'hours_rendered': '20'},
#  {'id': '2021018', 'hours_rendered': '17'},
#  {'id': '2021019', 'hours_rendered': '20'},
#  {'id': '2021020', 'hours_rendered': '18'}]

# %% [markdown]
# #### 3.2.2
#
# To retrieve details about individual interns quickly, it's best that we store intern data in a dictionary. This way, we simply lookup the details of the intern by key (in this case, the **id**).
#
# Create a dictionary variable named **interns_master_dict** that contains dictionaries for each entry in the intern master file file **./section3/interns-masterlist.csv**.

# %%
# CODE CELL
interns_master_dict = {}
# CODE START
with open("./section3/interns_masterlist.csv", newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        info_dict = {}
        info_dict["bank"] = row["bank"]
        info_dict["account_number"] = row["account_number"]
        info_dict["monthly_fee"] = row["monthly_fee"]
        info_dict["wfh"] = row["wfh"]
        interns_master_dict[row["id"]] = info_dict

    #print(str(interns_master_dict))
# CODE END

# sample dump of raw_log in interactive mode
interns_master_dict
# Out:
# {'2021001': {'bank': 'BPI',
#   'account_number': '1093 5000 5001',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021002': {'bank': 'BPI',
#   'account_number': '1093 5000 5002',
#   'monthly_fee': '3500',
#   'wfh': 'Y'},
#  '2021003': {'bank': 'BPI',
#   'account_number': '1093 5000 5003',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021004': {'bank': 'BPI',
#   'account_number': '1093 5000 5004',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021005': {'bank': 'BPI',
#   'account_number': '1093 5000 5005',
#   'monthly_fee': '6000',
#   'wfh': 'Y'},
#  '2021006': {'bank': 'BPI',
#   'account_number': '1093 5000 5006',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021007': {'bank': 'BPI',
#   'account_number': '1093 5000 5007',
#   'monthly_fee': '5000',
#   'wfh': 'Y'},
#  '2021008': {'bank': 'BPI',
#   'account_number': '1093 5000 5008',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021009': {'bank': 'BPI',
#   'account_number': '1093 5000 5009',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021010': {'bank': 'BPI',
#   'account_number': '1093 5000 5010',
#   'monthly_fee': '6000',
#   'wfh': 'N'},
#  '2021011': {'bank': 'BPI',
#   'account_number': '1093 5000 5011',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021012': {'bank': 'BPI',
#   'account_number': '1093 5000 5012',
#   'monthly_fee': '3500',
#   'wfh': 'N'},
#  '2021013': {'bank': 'BPI',
#   'account_number': '1093 5000 5013',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021014': {'bank': 'BPI',
#   'account_number': '1093 5000 5014',
#   'monthly_fee': '4500',
#   'wfh': 'N'},
#  '2021015': {'bank': 'BPI',
#   'account_number': '1093 5000 5015',
#   'monthly_fee': '5000',
#   'wfh': 'Y'},
#  '2021016': {'bank': 'BPI',
#   'account_number': '1093 5000 5016',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021017': {'bank': 'BPI',
#   'account_number': '1093 5000 5017',
#   'monthly_fee': '6000',
#   'wfh': 'Y'},
#  '2021018': {'bank': 'BPI',
#   'account_number': '1093 5000 5018',
#   'monthly_fee': '3500',
#   'wfh': 'Y'},
#  '2021019': {'bank': 'BPI',
#   'account_number': '1093 5000 5019',
#   'monthly_fee': '4500',
#   'wfh': 'Y'},
#  '2021020': {'bank': 'BPI',
#   'account_number': '1093 5000 5020',
#   'monthly_fee': '4500',
#   'wfh': 'Y'}}

# %% [markdown]
# #### 3.2.3
#
# Create a new list variable **interns_payroll** based on raw_logs but with an additional key takehome_pay for each dictionary entry.

# %%
# CODE CELL
interns_payroll = []
# CODE START
for timelog in raw_log:
    intern_payslip = {}
    #nts: organizing info for intern payslip
    intern_record = interns_master_dict[timelog["id"]]
    intern_payslip["id"] = timelog["id"]
    intern_payslip["hours_rendered"] = timelog["hours_rendered"]
    intern_payslip["monthly_fee"] = intern_record["monthly_fee"]
    #prorated pay
    prorated_pay = float(timelog["hours_rendered"])/20 * float(intern_record["monthly_fee"])
    intern_payslip["prorated_pay"] = prorated_pay

    #overtime pay
    intern_payslip["overtime_pay"] = get_overtime_pay(intern_record["monthly_fee"],timelog["hours_rendered"])

    #wfh allowance
    wfh_allowance = 0
    if intern_record["wfh"] == "Y":
        intern_payslip["wfh_allowance"] = 300
        wfh_allowance = 300

    #takehome pay
    intern_payslip["takehome_pay"] = get_pay(intern_record["monthly_fee"], float(timelog["hours_rendered"]), intern_payslip["overtime_pay"], wfh_allowance)
    interns_payroll.append(intern_payslip)

print(str(interns_payroll))
# CODE END
                 
# sample dump of payroll in interactive mode
interns_payroll
# Out:
# [{'id': '2021001', 'hours_rendered': '20', 'monthly_fee': '4500', 'prorated_pay': 4500.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 4800.0}, {'id': '2021002', 'hours_rendered': '17', 'monthly_fee': '3500', 'prorated_pay': 2975.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 3275.0}, {'id': '2021003', 'hours_rendered': '16', 'monthly_fee': '4500', 'prorated_pay': 3600.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 3900.0}, {'id': '2021004', 'hours_rendered': '15', 'monthly_fee': '4500', 'prorated_pay': 3375.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 3675.0}, {'id': '2021005', 'hours_rendered': '16', 'monthly_fee': '6000', 'prorated_pay': 4800.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 5100.0}, {'id': '2021006', 'hours_rendered': '18', 'monthly_fee': '4500', 'prorated_pay': 4050.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 4350.0}, {'id': '2021007', 'hours_rendered': '17', 'monthly_fee': '5000', 'prorated_pay': 4250.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 4550.0}, {'id': '2021008', 'hours_rendered': '17', 'monthly_fee': '4500', 'prorated_pay': 3825.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 4125.0}, {'id': '2021009', 'hours_rendered': '15', 'monthly_fee': '4500', 'prorated_pay': 3375.0, 'overtime_pay': 0.0, 'takehome_pay': 3375.0}, {'id': '2021010', 'hours_rendered': '18', 'monthly_fee': '6000', 'prorated_pay': 5400.0, 'overtime_pay': 0.0, 'takehome_pay': 5400.0}, {'id': '2021011', 'hours_rendered': '16', 'monthly_fee': '4500', 'prorated_pay': 3600.0, 'overtime_pay': 0.0, 'takehome_pay': 3600.0}, {'id': '2021012', 'hours_rendered': '20', 'monthly_fee': '3500', 'prorated_pay': 3500.0, 'overtime_pay': 0.0, 'takehome_pay': 3500.0}, {'id': '2021013', 'hours_rendered': '18', 'monthly_fee': '4500', 'prorated_pay': 4050.0, 'overtime_pay': 0.0, 'takehome_pay': 4050.0}, {'id': '2021014', 'hours_rendered': '22', 'monthly_fee': '4500', 'prorated_pay': 4950.0, 'overtime_pay': 900.0, 'takehome_pay': 5400.0}, {'id': '2021015', 'hours_rendered': '20', 'monthly_fee': '5000', 'prorated_pay': 5000.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 5300.0}, {'id': '2021016', 'hours_rendered': '25', 'monthly_fee': '4500', 'prorated_pay': 5625.0, 'overtime_pay': 2250.0, 'wfh_allowance': 300, 'takehome_pay': 7050.0}, {'id': '2021017', 'hours_rendered': '20', 'monthly_fee': '6000', 'prorated_pay': 6000.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 6300.0}, {'id': '2021018', 'hours_rendered': '17', 'monthly_fee': '3500', 'prorated_pay': 2975.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 3275.0}, {'id': '2021019', 'hours_rendered': '20', 'monthly_fee': '4500', 'prorated_pay': 4500.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 4800.0}, {'id': '2021020', 'hours_rendered': '18', 'monthly_fee': '4500', 'prorated_pay': 4050.0, 'overtime_pay': 0.0, 'wfh_allowance': 300, 'takehome_pay': 4350.0}]
# [{'id': '2021001',
#   'hours_rendered': '20',
#   'monthly_fee': '4500',
#   'prorated_pay': 4500.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4800.0},
#  {'id': '2021002',
#   'hours_rendered': '17',
#   'monthly_fee': '3500',
#   'prorated_pay': 2975.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3275.0},
#  {'id': '2021003',
#   'hours_rendered': '16',
#   'monthly_fee': '4500',
#   'prorated_pay': 3600.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3900.0},
#  {'id': '2021004',
#   'hours_rendered': '15',
#   'monthly_fee': '4500',
#   'prorated_pay': 3375.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3675.0},
#  {'id': '2021005',
#   'hours_rendered': '16',
#   'monthly_fee': '6000',
#   'prorated_pay': 4800.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 5100.0},
#  {'id': '2021006',
#   'hours_rendered': '18',
#   'monthly_fee': '4500',
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4350.0},
#  {'id': '2021007',
#   'hours_rendered': '17',
#   'monthly_fee': '5000',
#   'prorated_pay': 4250.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4550.0},
#  {'id': '2021008',
#   'hours_rendered': '17',
#   'monthly_fee': '4500',
#   'prorated_pay': 3825.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4125.0},
#  {'id': '2021009',
#   'hours_rendered': '15',
#   'monthly_fee': '4500',
#   'prorated_pay': 3375.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 3375.0},
#  {'id': '2021010',
#   'hours_rendered': '18',
#   'monthly_fee': '6000',
#   'prorated_pay': 5400.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 5400.0},
#  {'id': '2021011',
#   'hours_rendered': '16',
#   'monthly_fee': '4500',
#   'prorated_pay': 3600.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 3600.0},
#  {'id': '2021012',
#   'hours_rendered': '20',
#   'monthly_fee': '3500',
#   'prorated_pay': 3500.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 3500.0},
#  {'id': '2021013',
#   'hours_rendered': '18',
#   'monthly_fee': '4500',
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0.0,
#   'takehome_pay': 4050.0},
#  {'id': '2021014',
#   'hours_rendered': '22',
#   'monthly_fee': '4500',
#   'prorated_pay': 4950.0,
#   'overtime_pay': 900.0,
#   'takehome_pay': 5400.0},
#  {'id': '2021015',
#   'hours_rendered': '20',
#   'monthly_fee': '5000',
#   'prorated_pay': 5000.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 5300.0},
#  {'id': '2021016',
#   'hours_rendered': '25',
#   'monthly_fee': '4500',
#   'prorated_pay': 5625.0,
#   'overtime_pay': 2250.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 7050.0},
#  {'id': '2021017',
#   'hours_rendered': '20',
#   'monthly_fee': '6000',
#   'prorated_pay': 6000.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 6300.0},
#  {'id': '2021018',
#   'hours_rendered': '17',
#   'monthly_fee': '3500',
#   'prorated_pay': 2975.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 3275.0},
#  {'id': '2021019',
#   'hours_rendered': '20',
#   'monthly_fee': '4500',
#   'prorated_pay': 4500.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4800.0},
#  {'id': '2021020',
#   'hours_rendered': '18',
#   'monthly_fee': '4500',
#   'prorated_pay': 4050.0,
#   'overtime_pay': 0.0,
#   'wfh_allowance': 300,
#   'takehome_pay': 4350.0}]

# %% [markdown]
# #### 3.2.4
#
# Looping through the new list variable **payroll**, generate an intern payslip print spool file for the month of July. The time logs (as illustrated above) may be found in the file **./section3/interns-timelog-july2021.csv**.
#
# The output must be saved in a file named **./output/interns-payslips-july2021.txt**. The output looks like the following:
#
# ```
# Payroll Date   : July 31, 2021
# ID             : 2021001
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 20
# ------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021002
# Monthly Fee       : 3500
# ------------------------------
# Hours Rendered : 17
# ------------------------------
# Prorated Pay   : 2975.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 3275.0
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021013
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 18
# ------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# Takehome Pay   : 4050.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021014
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 22
# ------------------------------
# Prorated Pay   : 4950.0
# Overtime Pay   : 900.0
# Takehome Pay   : 5400.0
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021019
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 20
# ------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
# ______________________________
# Payroll Date   : July 31, 2021
# ID             : 2021020
# Monthly Fee       : 4500
# ------------------------------
# Hours Rendered : 18
# ------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4350.0
#
#
# ...
#
# ______________________________
# Payroll Date   : July 31, 2020
# ID             : 2021009
# Base Pay       : 4,500
# ------------------------------
# Hours Rendered : 15
# Takehome Pay   : 3,375.00
# ...
#
# ```
#
# **VERY IMPORTANT:** If the intern does not have a WFH allowance arrangement, **DO NOT** print out the line 'WFH Allowance'!!! The company does not want interns to ask about that if they see that line since it will open a can of worms.

# %%
# CODE CELL
import csv

filename = "./output/interns-payslips-july2021.txt"
payroll_run_date = "July 31, 2021"
# CODE START
payroll_run_date = "July 31, 2021"
f = open("./output/interns-payslips-july2021.txt", "w") 
for payroll in interns_payroll:
    f.write("Payroll Date   : " + payroll_run_date + "\n")
    f.write("ID             : " + payroll["id"] + "\n")
    f.write("Monthly Fee    : " + payroll["monthly_fee"] + "\n")
    f.write("-----------------------------------------" + "\n")
    f.write("Hours Rendered : " + payroll["hours_rendered"] + "\n")
    f.write("-----------------------------------------" + "\n")
    f.write("Prorated Pay   : " + str(payroll["prorated_pay"]) + "\n")
    f.write("Overtime Pay   : " + str(payroll["overtime_pay"]) + "\n")
    if payroll.get("wfh_allowance") != None:
        f.write("WFH Allowance  : " + str(payroll["wfh_allowance"]) + "\n")
    f.write("Takehome Pay   : " + str(payroll["takehome_pay"]) + "\n")
    f.write("\n\n")
# CODE END

# %%
# NON-EDITABLE CODE CELL
# You may run this cell, but do not edit it.

# See the output of your file
# !cat ./output/interns-payslips-july2021.txt
# Out:
# Payroll Date   : July 31, 2021
# ID             : 2021001
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 20
# -----------------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021002
# Monthly Fee    : 3500
# -----------------------------------------
# Hours Rendered : 17
# -----------------------------------------
# Prorated Pay   : 2975.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 3275.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021003
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 16
# -----------------------------------------
# Prorated Pay   : 3600.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 3900.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021004
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 15
# -----------------------------------------
# Prorated Pay   : 3375.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 3675.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021005
# Monthly Fee    : 6000
# -----------------------------------------
# Hours Rendered : 16
# -----------------------------------------
# Prorated Pay   : 4800.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 5100.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021006
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 18
# -----------------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4350.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021007
# Monthly Fee    : 5000
# -----------------------------------------
# Hours Rendered : 17
# -----------------------------------------
# Prorated Pay   : 4250.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4550.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021008
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 17
# -----------------------------------------
# Prorated Pay   : 3825.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4125.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021009
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 15
# -----------------------------------------
# Prorated Pay   : 3375.0
# Overtime Pay   : 0.0
# Takehome Pay   : 3375.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021010
# Monthly Fee    : 6000
# -----------------------------------------
# Hours Rendered : 18
# -----------------------------------------
# Prorated Pay   : 5400.0
# Overtime Pay   : 0.0
# Takehome Pay   : 5400.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021011
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 16
# -----------------------------------------
# Prorated Pay   : 3600.0
# Overtime Pay   : 0.0
# Takehome Pay   : 3600.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021012
# Monthly Fee    : 3500
# -----------------------------------------
# Hours Rendered : 20
# -----------------------------------------
# Prorated Pay   : 3500.0
# Overtime Pay   : 0.0
# Takehome Pay   : 3500.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021013
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 18
# -----------------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# Takehome Pay   : 4050.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021014
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 22
# -----------------------------------------
# Prorated Pay   : 4950.0
# Overtime Pay   : 900.0
# Takehome Pay   : 5400.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021015
# Monthly Fee    : 5000
# -----------------------------------------
# Hours Rendered : 20
# -----------------------------------------
# Prorated Pay   : 5000.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 5300.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021016
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 25
# -----------------------------------------
# Prorated Pay   : 5625.0
# Overtime Pay   : 2250.0
# WFH Allowance  : 300
# Takehome Pay   : 7050.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021017
# Monthly Fee    : 6000
# -----------------------------------------
# Hours Rendered : 20
# -----------------------------------------
# Prorated Pay   : 6000.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 6300.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021018
# Monthly Fee    : 3500
# -----------------------------------------
# Hours Rendered : 17
# -----------------------------------------
# Prorated Pay   : 2975.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 3275.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021019
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 20
# -----------------------------------------
# Prorated Pay   : 4500.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4800.0
#
#
# Payroll Date   : July 31, 2021
# ID             : 2021020
# Monthly Fee    : 4500
# -----------------------------------------
# Hours Rendered : 18
# -----------------------------------------
# Prorated Pay   : 4050.0
# Overtime Pay   : 0.0
# WFH Allowance  : 300
# Takehome Pay   : 4350.0

# %% [markdown]
# ### 3.3: For Consultants

# %% [markdown]
# Create a regular CSV named **./output/consultants_payouts_july2021.csv** containing consultant payout amounts. Use **./section3/consultants_masterlist.csv** as basis for the amounts, then don't forget to deduct 10% withholding tax.
#
# ```
# tin,net_pay
# 151-500-200-000,90000.00
# ...
# 151-500-202-000,100000.00
# ...
#
# ```

# %% [markdown]
# Create a dictionary **consultants_master_dict** containing lookups for consultants.

# %%
# CODE CELL
consultants_master_dict = {}
consultants_fees = []
# CODE START
with open("./section3/consultants_masterlist.csv", newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        bank_info = {}
        bank_info["bank"] = row["bank"]
        bank_info["account_number"] = row["account_number"]
        consultants_master_dict[row["tin"]] = bank_info

        

    #print(str(consultants_master_dict))
    #print(str(consultants_fees))
# CODE END
consultants_master_dict
# Out:
# {'151-500-200-000': {'bank': 'BPI', 'account_number': '1093 5000 6001'},
#  '151-500-201-000': {'bank': 'BPI', 'account_number': '1093 5000 6002'},
#  '151-500-202-000': {'bank': 'BDO', 'account_number': '0078 0000 0001'},
#  '151-500-203-000': {'bank': 'BPI', 'account_number': '1093 5000 6004'},
#  '151-500-204-000': {'bank': 'BPI', 'account_number': '1093 5000 6005'},
#  '151-500-205-000': {'bank': 'BPI', 'account_number': '1093 5000 6006'},
#  '151-500-206-000': {'bank': 'BDO', 'account_number': '0078 0000 0002'},
#  '151-500-207-000': {'bank': 'BDO', 'account_number': '0078 0000 0003'},
#  '151-500-208-000': {'bank': 'BPI', 'account_number': '1093 5000 6007'},
#  '151-500-209-000': {'bank': 'BPI', 'account_number': '1093 5000 6008'},
#  '151-500-210-000': {'bank': 'BPI', 'account_number': '1093 5000 6009'}}

# %% [markdown]
# Unlike the interns, we don't need to give consultants payslips. However, it would be easier to run "payroll" for consultants and store the results in a staging file. Run the consultants' "payroll" by keeping the results in a list variable called **consultants_payroll**. Each element of this list is based on a corresponding role in **./section3/consultants_masterlist.csv**. To make it easier, create a **consultants_fees** list variable by reading from this file.
#
# Then, generate a consultant payout file named **./output/consultants_payouts_july2021.csv**.

# %%
# CODE CELL
consultants_fees = []


# CODE START
with open("./section3/consultants_masterlist.csv", newline='') as csvfile:
    reader = csv.DictReader(csvfile)
    for row in reader:
        fees = {}
        fees["tin"] = row["tin"]
        fees["bank"] = row["bank"]
        fees["account_number"] = row["account_number"]
        fees["monthly_fee"] = row["monthly_fee"]
        fees["wfh"] = row["wfh"]
        consultants_fees.append(fees)

#print(str(consultants_payroll))

# CODE END

# dump output
consultants_fees
# Out:
# [{'tin': '151-500-200-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6001',
#   'monthly_fee': '100000',
#   'wfh': 'Y'},
#  {'tin': '151-500-201-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6002',
#   'monthly_fee': '50000',
#   'wfh': 'Y'},
#  {'tin': '151-500-202-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0001',
#   'monthly_fee': '111111.11',
#   'wfh': 'Y'},
#  {'tin': '151-500-203-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6004',
#   'monthly_fee': '100000',
#   'wfh': 'Y'},
#  {'tin': '151-500-204-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6005',
#   'monthly_fee': '65000',
#   'wfh': 'Y'},
#  {'tin': '151-500-205-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6006',
#   'monthly_fee': '130000',
#   'wfh': 'Y'},
#  {'tin': '151-500-206-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0002',
#   'monthly_fee': '50000',
#   'wfh': 'Y'},
#  {'tin': '151-500-207-000',
#   'bank': 'BDO',
#   'account_number': '0078 0000 0003',
#   'monthly_fee': '45000',
#   'wfh': 'Y'},
#  {'tin': '151-500-208-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6007',
#   'monthly_fee': '45000',
#   'wfh': 'N'},
#  {'tin': '151-500-209-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6008',
#   'monthly_fee': '60000',
#   'wfh': 'N'},
#  {'tin': '151-500-210-000',
#   'bank': 'BPI',
#   'account_number': '1093 5000 6009',
#   'monthly_fee': '45000',
#   'wfh': 'N'}]

# %%
# CODE CELL
#consultants_payroll = []

# CODE START
consultants_payroll = []
for fee in consultants_fees:
    payroll = {}
    payroll["tin"] = fee["tin"]
    payroll["net_pay"] = float(fee["monthly_fee"]) - 0.1 * float(fee["monthly_fee"])
    consultants_payroll.append(payroll)
#print(str(consultants_payroll))

with open('./output/consultants_payouts_july2021.csv', 'w', newline='') as csvfile:
    fieldnames = ['tin', 'net_pay']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()
    for c_pay in consultants_payroll:
        writer.writerow({'tin': c_pay["tin"], 'net_pay': c_pay["net_pay"]})
# CODE END

# sample dump of raw_log in interactive mode
consultants_payroll
# Out:
# [{'tin': '151-500-200-000', 'net_pay': 90000.0},
#  {'tin': '151-500-201-000', 'net_pay': 45000.0},
#  {'tin': '151-500-202-000', 'net_pay': 99999.999},
#  {'tin': '151-500-203-000', 'net_pay': 90000.0},
#  {'tin': '151-500-204-000', 'net_pay': 58500.0},
#  {'tin': '151-500-205-000', 'net_pay': 117000.0},
#  {'tin': '151-500-206-000', 'net_pay': 45000.0},
#  {'tin': '151-500-207-000', 'net_pay': 40500.0},
#  {'tin': '151-500-208-000', 'net_pay': 40500.0},
#  {'tin': '151-500-209-000', 'net_pay': 54000.0},
#  {'tin': '151-500-210-000', 'net_pay': 40500.0}]

# %% [markdown]
# To check if your payout file contents are correct, run `cat` (if using MacOS) or `type` (if using Windows). Don't forget the "!" character before the command. Replace `cat` with `type` if you are on Windows.

# %%
# !cat ./output/consultants_payouts_july2021.csv
# Out:
# tin,net_pay
# 151-500-200-000,90000.0
# 151-500-201-000,45000.0
# 151-500-202-000,99999.999
# 151-500-203-000,90000.0
# 151-500-204-000,58500.0
# 151-500-205-000,117000.0
# 151-500-206-000,45000.0
# 151-500-207-000,40500.0
# 151-500-208-000,40500.0
# 151-500-209-000,54000.0
# 151-500-210-000,40500.0

# %% [markdown]
# ### 3.4: Bank Credit Advise

# %% [markdown]
# **B. Bank Credit Advise**
#
# Generate a credit advise file each for BPI and BDO covering interns and consultants. The files must be named **./output/su-bpi-payment-advise.csv** and **./output/su-bdo-payment-advise.csv** respectively and should look like the following:
#
# ```
# account_number,amount
# 109350005001,4800.0
# 109350005002,3275.0
# ...
# 109350005003,3375.0
# ...
# 109350006001,9000
# ```

# %%
# CODE CELL
bpi_advise = []
bdo_advise = []

# CODE START
#BDO
with open('./output/su-bdo-payment-advise.csv', 'w', newline='') as csvfile:
    fieldnames = ['account_number', 'amount']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()

    for i_pay in interns_payroll:
        intern_info_dict = interns_master_dict[i_pay["id"]]
        if intern_info_dict["bank"] == "BDO":
            writer.writerow({'account_number': intern_info_dict["account_number"], 'amount': i_pay["takehome_pay"]})
            bdo_intern = {}
            bdo_intern["account_number"] = intern_info_dict["account_number"]
            bdo_intern["amount"] = i_pay["takehome_pay"]
            bdo_advise.append(bdo_intern)
            #print("bdo_advise:",bdo_advise) 

    for c_pay in consultants_payroll:
        cons_info_dict = consultants_master_dict[c_pay["tin"]]
        if cons_info_dict["bank"] == "BDO":
            writer.writerow({'account_number': cons_info_dict["account_number"], 'amount': c_pay["net_pay"]})
            bdo_consultants = {}
            bdo_consultants["account_number"] = cons_info_dict["account_number"]
            bdo_consultants["amount"] = c_pay["net_pay"]
            bdo_advise.append(bdo_consultants)
            #print("bdo_advise:",bdo_advise) 
    
#BPI
with open('./output/su-bpi-payment-advise.csv', 'w', newline='') as csvfile:
    fieldnames = ['account_number', 'amount']
    writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

    writer.writeheader()

    for i_pay in interns_payroll:
        intern_info_dict = interns_master_dict[i_pay["id"]]
        if intern_info_dict["bank"] == "BPI":
            writer.writerow({'account_number': intern_info_dict["account_number"], 'amount': i_pay["takehome_pay"]})
            bpi_intern = {}
            bpi_intern["account_number"] = intern_info_dict["account_number"]
            bpi_intern["amount"] = i_pay["takehome_pay"]
            bpi_advise.append(bpi_intern)
            #print("bpi_advise:",bpi_advise) 
            
    for c_pay in consultants_payroll:
        cons_info_dict = consultants_master_dict[c_pay["tin"]]
        if cons_info_dict["bank"] == "BPI":
            writer.writerow({'account_number': cons_info_dict["account_number"], 'amount': c_pay["net_pay"]})
            bpi_consultants = {}
            bpi_consultants["account_number"] = cons_info_dict["account_number"]
            bpi_consultants["amount"] = c_pay["net_pay"]
            bpi_advise.append(bpi_consultants)
            #print("bpi_advise:",bpi_advise) 
            

# CODE END

# %%
bpi_advise
# Out:
# [{'account_number': '1093 5000 5001', 'amount': 4800.0},
#  {'account_number': '1093 5000 5002', 'amount': 3275.0},
#  {'account_number': '1093 5000 5003', 'amount': 3900.0},
#  {'account_number': '1093 5000 5004', 'amount': 3675.0},
#  {'account_number': '1093 5000 5005', 'amount': 5100.0},
#  {'account_number': '1093 5000 5006', 'amount': 4350.0},
#  {'account_number': '1093 5000 5007', 'amount': 4550.0},
#  {'account_number': '1093 5000 5008', 'amount': 4125.0},
#  {'account_number': '1093 5000 5009', 'amount': 3375.0},
#  {'account_number': '1093 5000 5010', 'amount': 5400.0},
#  {'account_number': '1093 5000 5011', 'amount': 3600.0},
#  {'account_number': '1093 5000 5012', 'amount': 3500.0},
#  {'account_number': '1093 5000 5013', 'amount': 4050.0},
#  {'account_number': '1093 5000 5014', 'amount': 5400.0},
#  {'account_number': '1093 5000 5015', 'amount': 5300.0},
#  {'account_number': '1093 5000 5016', 'amount': 7050.0},
#  {'account_number': '1093 5000 5017', 'amount': 6300.0},
#  {'account_number': '1093 5000 5018', 'amount': 3275.0},
#  {'account_number': '1093 5000 5019', 'amount': 4800.0},
#  {'account_number': '1093 5000 5020', 'amount': 4350.0},
#  {'account_number': '1093 5000 6001', 'amount': 90000.0},
#  {'account_number': '1093 5000 6002', 'amount': 45000.0},
#  {'account_number': '1093 5000 6004', 'amount': 90000.0},
#  {'account_number': '1093 5000 6005', 'amount': 58500.0},
#  {'account_number': '1093 5000 6006', 'amount': 117000.0},
#  {'account_number': '1093 5000 6007', 'amount': 40500.0},
#  {'account_number': '1093 5000 6008', 'amount': 54000.0},
#  {'account_number': '1093 5000 6009', 'amount': 40500.0}]

# %%
bdo_advise
# Out:
# [{'account_number': '0078 0000 0001', 'amount': 99999.999},
#  {'account_number': '0078 0000 0002', 'amount': 45000.0},
#  {'account_number': '0078 0000 0003', 'amount': 40500.0}]

# %% [markdown]
# To check if your file outputs are correct, run either cat (on MacOS) or type (on Windows) below. Just replace `cat` with `type` if you're using Windows.

# %%
# !cat ./output/su-bpi-payment-advise.csv
# Out:
# account_number,amount
# 1093 5000 5001,4800.0
# 1093 5000 5002,3275.0
# 1093 5000 5003,3900.0
# 1093 5000 5004,3675.0
# 1093 5000 5005,5100.0
# 1093 5000 5006,4350.0
# 1093 5000 5007,4550.0
# 1093 5000 5008,4125.0
# 1093 5000 5009,3375.0
# 1093 5000 5010,5400.0
# 1093 5000 5011,3600.0
# 1093 5000 5012,3500.0
# 1093 5000 5013,4050.0
# 1093 5000 5014,5400.0
# 1093 5000 5015,5300.0
# 1093 5000 5016,7050.0
# 1093 5000 5017,6300.0
# 1093 5000 5018,3275.0
# 1093 5000 5019,4800.0
# 1093 5000 5020,4350.0
# 1093 5000 6001,90000.0
# 1093 5000 6002,45000.0
# 1093 5000 6004,90000.0
# 1093 5000 6005,58500.0
# 1093 5000 6006,117000.0
# 1093 5000 6007,40500.0
# 1093 5000 6008,54000.0
# 1093 5000 6009,40500.0

# %%
# !cat ./output/su-bdo-payment-advise.csv
# Out:
# account_number,amount
# 0078 0000 0001,99999.999
# 0078 0000 0002,45000.0
# 0078 0000 0003,40500.0
